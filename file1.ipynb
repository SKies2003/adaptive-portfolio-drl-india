# %%
# Load required libraries:

import random
import datetime as dt
import yfinance as yf
import talib as ta
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import random
import pandas as pd
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import linkage
from scipy.spatial.distance import squareform
from sklearn.covariance import LedoitWolf
from scipy.optimize import minimize
from sklearn.model_selection import train_test_split
import quantstats as qs
from scipy.optimize import minimize

start_train = dt.datetime(2014, 4, 1)
end_train = dt.datetime(2022, 9, 30)
start_test = dt.datetime(2022, 10, 1)
end_test = dt.datetime(2025, 3, 31)

start = start_train
end = end_test  

# Select five arbitrary stocks from some economic sectors:
banking_stocks = ['HDFCBANK.NS', 'ICICIBANK.NS', 'KOTAKBANK.NS', 'AXISBANK.NS', 'SBIN.NS']
energy_stocks = ['RELIANCE.NS', 'ONGC.NS', 'BPCL.NS', 'IOC.NS', 'NTPC.NS', 'POWERGRID.NS']
technology_stocks = ['TCS.NS', 'INFY.NS', 'WIPRO.NS', 'HCLTECH.NS', 'TECHM.NS']
consumer_stocks = ['HINDUNILVR.NS', 'ITC.NS', 'BRITANNIA.NS', 'NESTLEIND.NS', 'TITAN.NS']
consumer_discretionary_stocks = ['BAJFINANCE.NS', 'BAJAJFINSV.NS', 'ASIANPAINT.NS', 'HEROMOTOCO.NS', 'EICHERMOT.NS']
utilities_stocks = ['POWERGRID.NS', 'NTPC.NS']
healthcare_stocks = ['SUNPHARMA.NS', 'DRREDDY.NS', 'CIPLA.NS', 'DIVISLAB.NS', 'APOLLOHOSP.NS']
financial_stocks = ['HDFCLIFE.NS', 'BAJFINANCE.NS', 'BAJAJFINSV.NS', 'SBILIFE.NS', 'ICICIPRULI.NS']
real_estate_stocks = ['DLF.NS', 'GODREJPROP.NS']  # Not in Nifty50 but relevant in broader market
industrial_stocks = ['LTIM.NS', 'LTIM.NS', 'LT.NS', 'SIEMENS.NS', 'GRASIM.NS']
materials_stocks = ['JSWSTEEL.NS', 'TATASTEEL.NS', 'HINDALCO.NS', 'ULTRACEMCO.NS', 'SHREECEM.NS']
automobiles_stocks = ['MARUTI.NS', 'EICHERMOT.NS', 'TATAMOTORS.NS', 'BAJAJ-AUTO.NS', 'HEROMOTOCO.NS']

# Discard stock duplicate:
combined_stocks = list(set(
    banking_stocks +
    energy_stocks +
    technology_stocks +
    consumer_stocks +
    consumer_discretionary_stocks +
    utilities_stocks +
    healthcare_stocks +
    financial_stocks +
    real_estate_stocks +
    industrial_stocks +
    materials_stocks +
    automobiles_stocks
))

print("Combined list without duplicates:", combined_stocks)

# Create a list to store tickers with complete data:
valid_stocks = []

# Define the expected number of business days in the date range
trading_days = pd.date_range(start=start, end=end, freq='B')

for ticker in combined_stocks:
    data = yf.download(ticker, start=start, end=end)
    # Reindex the data to include all business days within the date range
    data = data.reindex(trading_days, method='ffill').dropna()
    # Check if the length of the data matches the number of trading days
    if len(data) == len(trading_days):
        valid_stocks.append(ticker)

print("Tickers with complete data:", valid_stocks)
# Load stocks with complete data:

print(f" you have {len(valid_stocks)} mix stocks in your portfolio.")
Tickers=valid_stocks

# Load data for valid_stocks:
stock_df = yf.download(Tickers, start=start, end=end, progress=False)
returns=stock_df['Close'].pct_change().dropna()

# Calculate the standard deviation of daily returns for each stock
volatility = returns.std()*np.sqrt(252)

# Sort the stocks by their volatility in descending order:
sorted_volatility = volatility.sort_values(ascending=False)
print( sorted_volatility)

# Add market features:
nsei_df=yf.download("^NSEI", start=start, end=end, progress=False)
vix_df=pd.read_csv(r"Data\India_Vix.csv", index_col=0, parse_dates=True)

# Add technical indicators as features:
def calculate_indicators(tickers, start, end):
    macd = []
    rsi = []
    cci = []
    adx = []
    stoch = []
    willr = []
    bb_upper = []
    bb_middle = []
    bb_lower = []
    mfi = []
    ema = []
    atr = []
    sar = []
    obv = []

    for ticker in tickers:
        try:
            stock_data = yf.download(ticker, start=start, end=end, progress=False)

            close_prices = stock_data['Close'].astype(np.float64).values.flatten()
            high_prices = stock_data['High'].astype(np.float64).values.flatten()
            low_prices = stock_data['Low'].astype(np.float64).values.flatten()
            volume = stock_data['Volume'].astype(np.float64).values.flatten()

            if close_prices.ndim > 1:
                close_prices = close_prices.flatten()
            if high_prices.ndim > 1:
                high_prices = high_prices.flatten()
            if low_prices.ndim > 1:
                low_prices = low_prices.flatten()
            if volume.ndim > 1:
                volume = volume.flatten()

            macd.append(ta.MACD(close_prices)[0])
            rsi.append(ta.RSI(close_prices))
            cci.append(ta.CCI(high_prices, low_prices, close_prices))
            adx.append(ta.ADX(high_prices, low_prices, close_prices))
            stoch_k, stoch_d = ta.STOCH(high_prices, low_prices, close_prices)
            stoch.append(stoch_k)  # Assuming you want to append %K line of Stochastic
            willr.append(ta.WILLR(high_prices, low_prices, close_prices))
            bb_upper_ticker, bb_middle_ticker, bb_lower_ticker = ta.BBANDS(close_prices)
            bb_upper.append(bb_upper_ticker)
            bb_middle.append(bb_middle_ticker)
            bb_lower.append(bb_lower_ticker)
            ema.append(ta.EMA(close_prices))
            atr.append(ta.ATR(high_prices, low_prices, close_prices))
            sar.append(ta.SAR(high_prices, low_prices ))
            obv.append(ta.OBV(close_prices, volume))

            # Calculate the Money Flow Index (MFI)
            mfi.append(ta.MFI(high=high_prices, low=low_prices, close=close_prices, volume=volume))

        except Exception as e:
            print(f"Error downloading data for {ticker}: {e}")

    return np.array(macd), np.array(rsi), np.array(cci), np.array(adx), np.array(stoch), np.array(willr), np.array(bb_upper), np.array(bb_middle), np.array(bb_lower), np.array(mfi), np.array(ema), np.array(atr), np.array(sar), np.array(obv)


# Function to handle NaNs
def handle_nans(indicators, fill_value=0):
    inds_nan = np.isnan(indicators)
    if inds_nan.any():
        indicators = np.where(inds_nan, fill_value, indicators)
    return indicators

# Function to normalize indicators:
def normalize_indicators(indicators):
    indicators = handle_nans(indicators)  # Handle NaNs before normalization
    if indicators.ndim == 1:
        indicators = indicators.reshape(-1, 1)  # Reshape 1D array to 2D array

    min_val = np.min(indicators, axis=1, keepdims=True)
    max_val = np.max(indicators, axis=1, keepdims=True)

    # Avoid divide-by-zero error by adding a small epsilon
    epsilon = 1e-8
    normalized = (indicators - min_val) / (max_val - min_val + epsilon)

    print(f"Normalized indicators shape: {normalized.shape}")
    return normalized

# Normalize nsei and VIX :
normalized_nsei = normalize_indicators(nsei_df['Close'].values)
normalized_vix = normalize_indicators(vix_df['Close'].values)
print(f"Normalized nsei shape: {normalized_nsei.shape}")
print(f"Normalized VIX shape: {normalized_vix.shape}")

indicators = calculate_indicators(Tickers, start, end)

# Normalize indicators and store them in a dictionary:

normalized_indicators = {}
indicator_names = ['macd', 'rsi', 'cci', 'adx', 'stoch', 'willr', 'bb_upper', 'bb_middle', 'bb_lower', 'mfi', 'ema', 'atr', 'sar', 'obv']
for i, name in enumerate(indicator_names):
    normalized_indicators[name] = normalize_indicators(indicators[i])

# Checking shapes
for name in normalized_indicators:
    print(f"{name} shape: {normalized_indicators[name].shape}")

normalized_nsei=normalize_indicators(nsei_df['Close'].values)
normalized_vix=normalize_indicators(vix_df['Close'].values)

# Initialize parameters for model:

D = len(Tickers)

# state_dim = (14 technical indicators+ holdings)*D+ NSEI + VIX + balance + portfolio value:

state_dim = 15 * D + 4  # (14 technical indicators+ holdings)*D+ 
action_dim = D * 3  # Actions: Buy, Sell, Hold for each ticker
print(f"Calculated state dimension: {state_dim}")

# Data into training and testing sets:
train_df = stock_df.loc[start_train:end_train]
test_df = stock_df.loc[start_test:end_test]
train_nsei = nsei_df.loc[start_train:end_train]
test_nsei = nsei_df.loc[start_test:end_test]
train_vix = vix_df.loc[start_train:end_train]
test_vix = vix_df.loc[start_test:end_test]


class PPO(nn.Module):
  def __init__(self, state_dim, action_dim):
    super(PPO, self).__init__()
    self.fc1 = nn.Linear(state_dim, 256)
    self.fc2 = nn.Linear(256, 128)
    self.dropout = nn.Dropout(0.2)
    self.actor = nn.Linear(128, action_dim)  
    self.critic = nn.Linear(128, 1)  

  def forward(self, x):
    x = torch.relu(self.fc1(x))
    x = self.dropout(x)
    x = torch.relu(self.fc2(x))
    action_probs = torch.softmax(self.actor(x), dim=-1)
    state_value = self.critic(x)
    return action_probs, state_value

# Ensure proper initialization
def init_weights(m):
  if type(m) == nn.Linear:
    nn.init.xavier_uniform_(m.weight)
    m.bias.data.fill_(0.01)

def initialize_ppo_model(device):
    """
    Initialize the PPO model, optimizer, and loss function.
    """
    model = PPO(state_dim, action_dim).to(device)
    model.apply(init_weights)
    optimizer = optim.Adam(model.parameters(), lr=1e-4)
    mse_loss = nn.MSELoss()
    return model, optimizer, mse_loss

def init_weights(m):
    if type(m) == nn.Linear:
        nn.init.xavier_uniform_(m.weight)
        m.bias.data.fill_(0.01)

def ppo_update(model, optimizer, mse_loss, memory, gamma, clip_epsilon, device, update_steps, batch_size):
    for _ in range(update_steps):
        if len(memory) < batch_size:
            continue  # Skip if not enough samples

        batch_indices = np.random.choice(len(memory), batch_size)
        batch = [memory[i] for i in batch_indices]

        states, actions, rewards, old_probs, next_states = zip(*batch)

        states = torch.stack(states).to(device).float()
        next_states = torch.stack(next_states).to(device).float()
        actions = torch.tensor(actions).to(device).long()
        old_probs = torch.tensor(old_probs).to(device).float()
        rewards = torch.tensor(rewards).to(device).float().unsqueeze(-1)  # shape [B, 1]

        new_probs, state_values = model(states)
        _, next_state_values = model(next_states)

        # Compute advantages
        with torch.no_grad():
            target_values = rewards + gamma * next_state_values
            advantages = target_values - state_values

        # Normalize advantages
        advantages = (advantages - advantages.mean()) / (advantages.std() + 1e-8)

        # Get new log probs of taken actions
        new_probs = new_probs.gather(1, actions.unsqueeze(1))

        # Compute ratio
        ratio = new_probs / (old_probs.unsqueeze(-1) + 1e-8)
        clipped_ratio = torch.clamp(ratio, 1 - clip_epsilon, 1 + clip_epsilon)

        actor_loss = -torch.min(ratio * advantages, clipped_ratio * advantages).mean()
        critic_loss = mse_loss(state_values, target_values)

        loss = actor_loss + critic_loss

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

'''    
The advantage of PPO is its flexibility and robustness to different settings, so one can experiment with its hyperparameters to see what works best for each scenario.
'''

def train_ppo(train_df, episodes=250, gamma=0.997, epsilon=0.08, clip_epsilon=0.15, 
              update_steps=20, batch_size=128, early_stop_threshold=0.002, patience=60, lr=0.0005):
    """
    Trains a Proximal Policy Optimization (PPO) model for stock trading.

    Args:
        train_df (pd.DataFrame): DataFrame containing historical stock data.
        episodes (int, optional): Number of training episodes. Defaults to 100.
        gamma (float, optional): Discount factor for future rewards. Defaults to 0.99.
        epsilon (float, optional): Probability of taking a random action. Defaults to 0.1.
        clip_epsilon (float, optional): Clipping parameter for PPO. Defaults to 0.2.
        update_steps (int, optional): Number of PPO update steps per batch. Defaults to 10.
        batch_size (int, optional): Batch size for PPO updates. Defaults to 32.
        early_stop_threshold (float, optional): Early stopping threshold for average reward improvement. Defaults to 0.001.
        patience (int, optional): Number of episodes to wait for improvement before early stopping. Defaults to 10.

    Returns:
        tuple: A tuple containing the final holdings, final portfolio value, list of tickers with buy or hold actions,
               normalized final weights of tickers, and a DataFrame of final selected tickers and their weights.
    """

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = PPO(state_dim, action_dim).to(device)
    model.apply(init_weights)
    optimizer = optim.Adam(model.parameters(), lr=lr)
    mse_loss = nn.MSELoss()

    tickers_with_last_buy_or_hold = set()
    total_iterations = 0

    final_holdings = None
    final_portfolio_value = None
    rewards_history = []
    portfolio_values_history = []
    best_avg_reward = -float('inf')
    patience_counter = 0

    for episode in range(episodes):
        initial_holdings = np.zeros(D)
        initial_balance = 100000
        initial_portfolio_value = initial_balance + np.sum(train_df['Close'].iloc[0] * initial_holdings)
        current_step = 0

        holdings = initial_holdings.copy()
        balance = initial_balance
        portfolio_value = initial_portfolio_value

        episode_rewards = []
        memory = []

        while current_step < len(train_df) - 1:
            state_components = []
            for i, ticker in enumerate(Tickers):
                for name in indicator_names:
                    state_components.append(normalized_indicators[name][i, current_step])
            state_components.extend([normalized_nsei[current_step, 0], normalized_vix[current_step, 0]])
            state_components.extend(holdings)
            state_components.extend([balance, portfolio_value])
            state = torch.FloatTensor(state_components).float().to(device)

            action_probs, state_value = model(state)

            if torch.isnan(action_probs).any() or torch.isinf(action_probs).any():
                raise ValueError("NaNs or Infs found in action probabilities")

            if random.random() < epsilon:
                action = random.randint(0, action_dim - 1)
            else:
                action = torch.argmax(action_probs).item()

            action_type = action % 3
            ticker_idx = action // 3
            action_desc = ['hold', 'buy', 'sell'][action_type]

            if action_desc in ['buy', 'hold']:
                tickers_with_last_buy_or_hold.add(Tickers[ticker_idx])
            else:
                tickers_with_last_buy_or_hold.discard(Tickers[ticker_idx])

            next_prices = train_df['Close'].iloc[current_step + 1]
            next_portfolio_value = balance + np.sum(next_prices * holdings)

            max_shares = 3
            price = next_prices.iloc[ticker_idx]
            if action_desc == 'buy' and balance >= price:
                shares = 1
                holdings[ticker_idx] += shares
                balance -= shares * price
            elif action_desc == 'sell' and holdings[ticker_idx] > 0:
                shares = min(holdings[ticker_idx], max_shares)
                holdings[ticker_idx] -= shares
                balance += shares * price


            transaction_cost = 0.0002  # ~0.02% penalty
            drawdown = max(0, (portfolio_value - next_portfolio_value) / portfolio_value)
            reward = (next_portfolio_value - portfolio_value) / portfolio_value
            reward -= transaction_cost * (action_type != 0)
            reward -= 0.005 * drawdown  # penalize sharp drops
            # portfolio_volatility = np.std(holdings * train_df['Close'].pct_change().iloc[current_step])
            # reward -= 0.01 * portfolio_volatility
            episode_rewards.append(reward)
            portfolio_value = next_portfolio_value

            next_state_components = []
            for i, ticker in enumerate(Tickers):
                for name in indicator_names:
                    next_state_components.append(normalized_indicators[name][i, current_step + 1])
            next_state_components.extend([normalized_nsei[current_step + 1, 0], normalized_vix[current_step + 1, 0]])
            next_state_components.extend(holdings)
            next_state_components.extend([balance, portfolio_value])
            next_state = torch.FloatTensor(next_state_components).float().to(device)

            _, next_state_value = model(next_state)
            advantage = reward + gamma * next_state_value.item() - state_value.item()
            target_value = torch.FloatTensor([reward + gamma * next_state_value.item() + 1e-8]).to(device).view_as(state_value)
            critic_loss = mse_loss(state_value, target_value)
            actor_loss = -torch.log(action_probs[action] + 1e-8) * advantage
            loss = actor_loss + critic_loss

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            memory.append((state, action, reward, action_probs[action].item(), next_state))
            current_step += 1

            if len(memory) >= 128:
                ppo_update(model, optimizer, mse_loss, memory, gamma, clip_epsilon, device, update_steps, batch_size)
                memory = []

        final_holdings = holdings
        final_portfolio_value = portfolio_value
        total_reward = np.sum(episode_rewards)
        rewards_history.append(total_reward)
        portfolio_values_history.append(portfolio_value)

        avg_reward = np.mean(rewards_history[-patience:])
        print(f"Episode {episode+1}/{episodes}, Reward: {total_reward}, Avg Reward: {avg_reward}")

        if avg_reward > best_avg_reward + early_stop_threshold:
            best_avg_reward = avg_reward
            patience_counter = 0
        else:
            patience_counter += 1

        if patience_counter >= patience:
            print(f"Early stopping at episode {episode+1}")
            break

    tickers_list = list(tickers_with_last_buy_or_hold)
    print(f"Tickers with 'buy' or 'hold' actions at the end of the last iteration: {tickers_with_last_buy_or_hold}")
    print("Final portfolio value:", final_portfolio_value)
    print("Final holdings:")
    for i, ticker in enumerate(Tickers):
        print(f"{ticker} holdings: {final_holdings[i]}")

    weights = final_holdings * train_df['Close'].iloc[-1]
    total_weights = np.sum(weights)
    normalized_weights = weights / total_weights

    final_weights_df = pd.DataFrame({
        'Ticker': Tickers,
        'Weight': normalized_weights
    })

    plt.figure(figsize=(12, 6))
    plt.plot(rewards_history, label='Rewards')
    plt.xlabel('Episode')
    plt.ylabel('Total Reward')
    plt.title('Reward History')
    plt.legend()
    plt.show()

    plt.figure(figsize=(12, 6))
    plt.plot(portfolio_values_history, label='Portfolio Value')
    plt.xlabel('Episode')
    plt.ylabel('Portfolio Value')
    plt.title('Portfolio Values History')
    plt.legend()
    plt.show()

    return final_holdings, final_portfolio_value, tickers_list, normalized_weights, final_weights_df


# Train the PPO model
final_holdings, final_portfolio_value, tickers_list, normalized_weights, final_weights_df = train_ppo(train_df )

# Display results
print("Best Holdings:", final_holdings)
print("Best Portfolio Value:", final_portfolio_value)
print("Tickers with Last Buy or Hold:", tickers_list)
print("Best Weights:", normalized_weights)


# Define comparison portfolios:

def calculate_cvar(returns, confidence_level=0.95):
    """
    Calculates the Conditional Value at Risk (CVaR) of a portfolio.

    Args:
        returns (np.ndarray): Array of portfolio returns.
        confidence_level (float, optional): Confidence level for VaR calculation. Defaults to 0.95.

    Returns:
        float: The Conditional Value at Risk (CVaR) of the portfolio.
    """
    # Calculate VaR
    var = np.percentile(returns, 100 * (1 - confidence_level))

    # Calculate CVaR
    cvar = returns[returns <= var].mean()

    return cvar

# Define mean conditional value-at-risk algorithm:

def mCVAR_optimization(returns, confidence_level=0.95):
    """
    Optimizes the portfolio weights to minimize Mean Conditional Value at Risk (mCVaR).

    Args:
        returns (pd.DataFrame): DataFrame containing historical stock returns.
        confidence_level (float, optional): Confidence level for VaR calculation. Defaults to 0.95.

    Returns:
        np.ndarray: Optimal portfolio weights that minimize mCVaR.
    """
    tickers = returns.columns
    n_tickers = len(tickers)

    # Objective function to minimize mCVaR
    def objective(weights):
        portfolio_returns = returns.dot(weights)
        return calculate_cvar(portfolio_returns, confidence_level)

    # Constraints: Weights sum to 1
    constraints = ({
        'type': 'eq',
        'fun': lambda weights: np.sum(weights) - 1
    })

    # Bounds: Weights between 0 and 1
    bounds = [(0, 1)] * n_tickers

    # Initial guess for weights (equal distribution)
    initial_weights = np.ones(n_tickers) / n_tickers

    # Minimize the objective function
    result = minimize(objective, initial_weights, bounds=bounds, constraints=constraints)

    return result.x


# Definie Hierarchical Risk Parity algorithm:

def get_IVP(cov, **kargs):
    ivp = 1. / np.diag(cov)
    ivp /= ivp.sum()
    return ivp

def get_cluster_var(cov, cItems):
    cov_ = cov.loc[cItems, cItems]
    w_ = get_IVP(cov_).reshape(-1, 1)
    cVar = np.dot(np.dot(w_.T, cov_), w_)[0, 0]
    return cVar

def get_quasi_diag(link):
    link = link.astype(int)
    sortIx = pd.Series([link[-1, 0], link[-1, 1]])
    numItems = link[-1, 3]
    while sortIx.max() >= numItems:
        sortIx.index = range(0, sortIx.shape[0] * 2, 2)
        df0 = sortIx[sortIx >= numItems]
        i = df0.index
        j = df0.values - numItems
        sortIx[i] = link[j, 0]
        df0 = pd.Series(link[j, 1], index=i + 1)
        sortIx = pd.concat([sortIx, df0])
        sortIx = sortIx.sort_index()
        sortIx.index = range(sortIx.shape[0])
    return sortIx.tolist()

def get_rec_bipart(cov, sortIx):
    w = pd.Series(1.0, index=sortIx)  # Ensure w is of float type
    cItems = [sortIx]
    while len(cItems) > 0:
        cItems = [i[int(j):int(k)] for i in cItems for j, k in ((0, len(i) / 2), (len(i) / 2, len(i))) if len(i) > 1]
        for i in range(0, len(cItems), 2):
            cItems0 = cItems[i]
            cItems1 = cItems[i + 1]
            cVar0 = get_cluster_var(cov, cItems0)
            cVar1 = get_cluster_var(cov, cItems1)
            alpha = float(1 - cVar0 / (cVar0 + cVar1))  # Explicitly cast alpha to float
            w[cItems0] *= alpha
            w[cItems1] *= 1 - alpha
    return w

def HRP_Allocation(returns):
    cov = returns.cov()
    corr = returns.corr()
    dist = squareform(((1 - corr) / 2.)**.5)
    link = linkage(dist, 'single')
    sortIx = get_quasi_diag(link)
    sortIx = returns.columns[sortIx].tolist()
    hrp = get_rec_bipart(cov, sortIx)
    return hrp.sort_index()

# Mean variance optimization (MVO) algorithm:

def optimize_portfolio(returns):
    mean_returns = returns.mean()
    cov_matrix = returns.cov()

    def portfolio_performance(weights):
        portfolio_returns = np.dot(weights, mean_returns)
        portfolio_volatility = np.sqrt(np.dot(weights.T, np.dot(cov_matrix, weights)))
        return portfolio_returns, portfolio_volatility

    def negative_sharpe_ratio(weights, risk_free_rate=0):
        p_returns, p_volatility = portfolio_performance(weights)
        return - (p_returns - risk_free_rate) / p_volatility

    constraints = ({'type': 'eq', 'fun': lambda weights: np.sum(weights) - 1})
    bounds = tuple((0, 1) for _ in range(returns.shape[1]))
    initial_guess = returns.shape[1] * [1. / returns.shape[1]]

    optimized_result = minimize(negative_sharpe_ratio, initial_guess,
                                method='SLSQP', bounds=bounds,
                                constraints=constraints)

    return optimized_result.x


# Display the head of train and test returns dataframes
# print("Train Returns:")
# # print(train_returns.head())

# print("\nTest Returns:")
# # print(test_returns.head())


# Function to calculate portfolio returns:
def calculate_portfolio_returns(weights, test_returns):
    portfolio_returns = (weights * test_returns).sum(axis=1)
    cumulative_returns = (1 + portfolio_returns).cumprod()-1
    return cumulative_returns

# Align indices of returns with stock_df data:
returns_df = returns.reindex(stock_df.index)

# Split the data into train and test sets
# train_df, test_df = train_test_split(stock_df, test_size=0.2, shuffle=False)

# Get the indices for train and test data
train_indices = train_df.index
test_indices = test_df.index

# Filter the returns dataframe using the train and test indices
train_returns = returns_df.loc[start_train:end_train]
test_returns = returns_df.loc[start_test:end_test]

train_returns = train_returns.dropna(axis=0, how='any')
test_returns = test_returns.dropna(axis=0, how='any')

# Display the head of the correctly split train and test returns dataframes
print("\nTrain Returns (using manual dates):")
print(train_returns.head())
print(f"Shape: {train_returns.shape}")


print("\nTest Returns (using manual dates):")
print(test_returns.head())
print(f"Shape: {test_returns.shape}")

# Filter the test returns to include only the selected tickers returned by PPO model:

selected_tickers = final_weights_df['Ticker']
test_returns_filtered = test_returns[selected_tickers]

# Convert the weights to a numpy array
drl_weights = final_weights_df['Weight'].values

# Calculate the portfolio returns on the test data
drl_portfolio_returns = test_returns_filtered.dot(drl_weights)

# Calculate cumulative returns for the portfolio
drl_cumulative_returns = (1 + drl_portfolio_returns).cumprod() - 1

# Display the portfolio returns and cumulative returns
print("DRL Portfolio Returns on Test Data:")
print(drl_portfolio_returns.head())

print("\nDRL Cumulative Returns on Test Data:")
print(drl_cumulative_returns.head())

# MVO portfolio on test data:

# Optimize portfolio using train returns:
mvo_weights = optimize_portfolio(train_returns)
print(mvo_weights)
mvo_portfolio_returns = test_returns.dot(mvo_weights)
mvo_cumulative_returns = calculate_portfolio_returns(mvo_weights, test_returns)

# HRP portfolio on test data:

hrp_weights = HRP_Allocation(train_returns)

print("HRP train weights:\n")
print(hrp_weights)
print()

hrp_portfolio_returns = test_returns.dot(hrp_weights)
hrp_cumulative_returns = calculate_portfolio_returns(hrp_weights, test_returns)

# MCVAR portfolio on test data:
mcvar_weights = mCVAR_optimization(train_returns)
print(" mCVAR Optimal Portfolio Weights:", mcvar_weights)
mcvar_portfolio_returns = test_returns.dot(mcvar_weights)
mcvar_cumulative_returns = calculate_portfolio_returns(mcvar_weights, test_returns)

# Create DataFrames to compare HRP , MVO and DRL  performance:

performance_df = pd.DataFrame({
    'DRL Cumulative Returns': drl_cumulative_returns,
    'MVO Cumulative Returns': mvo_cumulative_returns,
    'HRP Cumulative Returns': hrp_cumulative_returns,
    'mCVAR Cumulative Returns': mcvar_cumulative_returns
})

print("Performance Comparison:\n", performance_df)

# Plot the performance:
performance_df.plot(title="DRL vs HRP vs MVO vs mCVAR Performance")


mvo_last_cumulative_return = mvo_cumulative_returns.iloc[-1]
hrp_last_cumulative_return = hrp_cumulative_returns.iloc[-1]
drl_last_cumulative_return = drl_cumulative_returns.iloc[-1]
mcvar_last_cumulative_return = mcvar_cumulative_returns.iloc[-1]

last_cumul = {
    'cumulative_returns[-1]': [
        mvo_last_cumulative_return,
        hrp_last_cumulative_return,
        drl_last_cumulative_return,
        mcvar_last_cumulative_return
    ]
}

port_names = ['MVO', 'HRP', 'DRL', 'mCVAR']

cumul_df = pd.DataFrame(last_cumul, index=port_names)

print(cumul_df)


# Use quantstats to define the function to calculate performance metrics :

# Existing portfolio data
portfolios = {
    "MVO Portfolio": mvo_portfolio_returns,
    "HRP Portfolio": hrp_portfolio_returns,
    "DRL Portfolio": drl_portfolio_returns,
    "mCVAR Portfolio": mcvar_portfolio_returns
}

# List of metrics to store
metrics = ['Sharpe Ratio', 'Omega Ratio', 'Volatility', 'Max Drawdown', 'Sortino Ratio', 'Calmar Ratio', 'Tail Ratio', 'Risk Return', 'Skew', 'Kurtosis']

# Create an empty dictionary to store the metrics
metrics_data = {'Metrics': metrics}

# Initialize risk-free rate
risk_free_rate = 0.0419

# Function to calculate performance metrics:

def calculate_performance_metrics(returns, risk_free_rate=0.0):
    returns_series = pd.Series(returns).dropna()
    
    # Fix: Make sure returns are properly formatted for quantstats functions
    sharpe_ratio = qs.stats.sharpe(returns_series, rf=risk_free_rate, periods=252, annualize=True)
    
    # Fix: For omega ratio, convert Series to numeric values if needed
    try:
        # Pass the Series directly instead of converting to DataFrame
        omega_ratio = qs.stats.omega(returns_series, required_return=0.0, rf=risk_free_rate, periods=252)
    except Exception as e:
        print(f"Error calculating Omega ratio: {e}")
        omega_ratio = None
        
    volatility = qs.stats.volatility(returns_series, periods=252, annualize=True)
    max_drawdown = qs.stats.max_drawdown(returns_series)
    sortino_ratio = qs.stats.sortino(returns_series, rf=risk_free_rate, periods=252)
    
    # Fix: For functions that use prepare_returns, set it to False since we're already passing returns
    calmar_ratio = qs.stats.calmar(returns_series)
    tail_ratio = qs.stats.tail_ratio(returns_series, cutoff=0.95)
    risk_return = qs.stats.risk_return_ratio(returns_series)
    skew = qs.stats.skew(returns_series)
    kurtosis = qs.stats.kurtosis(returns_series)

    return {
        'Sharpe Ratio': sharpe_ratio,
        'Omega Ratio': omega_ratio,
        'Volatility': volatility,
        'Max Drawdown': max_drawdown,
        'Sortino Ratio': sortino_ratio,
        'Calmar Ratio': calmar_ratio,
        'Tail Ratio': tail_ratio,
        'Risk Return': risk_return,
        'Skew': skew,
        'Kurtosis': kurtosis
    }

# Calculate metrics for each portfolio and store in the dictionary:

for name, returns in portfolios.items():
    print(f"\nPerformance Metrics for {name}:")
    performance_metrics = calculate_performance_metrics(returns, risk_free_rate)
    metrics_data[name] = [performance_metrics[metric] for metric in metrics]

# Convert the dictionary to a DataFrame
metrics_df = pd.DataFrame(metrics_data)
metrics_df.set_index('Metrics', inplace=True)

# Display the DataFrame
print(metrics_df)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Combined list without duplicates: ['MARUTI.NS', 'HDFCBANK.NS', 'TCS.NS', 'GODREJPROP.NS', 'HEROMOTOCO.NS', 'ONGC.NS', 'DIVISLAB.NS', 'ULTRACEMCO.NS', 'NTPC.NS', 'NESTLEIND.NS', 'POWERGRID.NS', 'APOLLOHOSP.NS', 'HINDALCO.NS', 'TITAN.NS', 'LT.NS', 'BAJAJ-AUTO.NS', 'HINDUNILVR.NS', 'IOC.NS', 'DRREDDY.NS', 'ICICIPRULI.NS', 'SUNPHARMA.NS', 'ASIANPAINT.NS', 'DLF.NS', 'GRASIM.NS', 'SBIN.NS', 'BAJFINANCE.NS', 'LTIM.NS', 'SHREECEM.NS', 'INFY.NS', 'KOTAKBANK.NS', 'CIPLA.NS', 'HDFCLIFE.NS', 'ICICIBANK.NS', 'TATAMOTORS.NS', 'BRITANNIA.NS', 'JSWSTEEL.NS', 'WIPRO.NS', 'TECHM.NS', 'TATASTEEL.NS', 'SIEMENS.NS', 'AXISBANK.NS', 'ITC.NS', 'RELIANCE.NS', 'EICHERMOT.NS', 'SBILIFE.NS', 'HCLTECH.NS', 'BPCL.NS', 'BAJAJFINSV.NS']
# [*********************100%***********************]  1 of 1 completed
# ...

# %%
# --- Visualization 1: Input Stock Volatility ---
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(15, 7))
# Assuming 'sorted_volatility' Series exists from your main code
sns.barplot(x=sorted_volatility.index, y=sorted_volatility.values, palette='viridis')
plt.xticks(rotation=90, fontsize=8)
plt.ylabel('Annualized Volatility (Std Dev)')
plt.title('Annualized Volatility of Stocks in the Portfolio (2014-2025)')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\gagan\AppData\Local\Temp\ipykernel_3372\901981731.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=sorted_volatility.index, y=sorted_volatility.values, palette='viridis')

# %%
# --- Visualization 3: Final DRL Portfolio Allocation ---
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# Assuming 'normalized_weights' Series exists from your main code
# Filter out stocks with zero weight for clarity
final_weights_no_zero = normalized_weights[normalized_weights > 1e-4] # Use a small threshold

if not final_weights_no_zero.empty:
    plt.figure(figsize=(15, 7))
    sns.barplot(x=final_weights_no_zero.index, y=final_weights_no_zero.values, palette='magma')
    plt.xticks(rotation=90, fontsize=8)
    plt.ylabel('Portfolio Weight')
    plt.title('Final Portfolio Allocation by DRL Agent (End of Training)')
    plt.tight_layout()
    plt.show()
else:
    print("No significant weights found in the DRL portfolio.")

# Alternative: Pie chart (better for fewer assets)
# if not final_weights_no_zero.empty and len(final_weights_no_zero) <= 10:
#     plt.figure(figsize=(10, 10))
#     plt.pie(final_weights_no_zero, labels=final_weights_no_zero.index, autopct='%1.1f%%', startangle=140)
#     plt.title('Final Portfolio Allocation by DRL Agent (End of Training)')
#     plt.show()
# elif not final_weights_no_zero.empty:
#     print("Too many assets for a clear pie chart, using bar chart instead.")
# Out:
# C:\Users\gagan\AppData\Local\Temp\ipykernel_3372\4063897080.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=final_weights_no_zero.index, y=final_weights_no_zero.values, palette='magma')

# %%
# --- Visualization 4: Cumulative Returns Comparison (Test Period) ---
import matplotlib.pyplot as plt

# Assuming 'performance_df' DataFrame exists from your main code
plt.figure(figsize=(14, 7))
plt.plot(performance_df.index, performance_df['DRL Cumulative Returns'], label='DRL (PPO)')
plt.plot(performance_df.index, performance_df['MVO Cumulative Returns'], label='MVO')
plt.plot(performance_df.index, performance_df['HRP Cumulative Returns'], label='HRP')
plt.plot(performance_df.index, performance_df['mCVAR Cumulative Returns'], label='mCVAR')

plt.title('Cumulative Returns Comparison on Test Data (2022-10 to 2025-03)')
plt.xlabel('Date')
plt.ylabel('Cumulative Returns')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# --- Visualization 5: Performance Metrics Comparison ---
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Assuming 'metrics_df' DataFrame exists from your main code
# Select key metrics to plot (or plot all if desired)
metrics_to_plot = ['Sharpe Ratio', 'Sortino Ratio', 'Max Drawdown', 'Volatility', 'Calmar Ratio']
plot_data = metrics_df.loc[metrics_to_plot].T # Transpose for easier plotting

plot_data.plot(kind='bar', figsize=(15, 7), colormap='viridis')
plt.title('Performance Metrics Comparison on Test Data')
plt.ylabel('Metric Value')
plt.xlabel('Portfolio Strategy')
plt.xticks(rotation=0)
plt.axhline(0, color='grey', linewidth=0.8) # Add a line at zero for reference
plt.legend(title='Metrics')
plt.tight_layout()
plt.show()

# --- Alternative: Heatmap for all metrics ---
# plt.figure(figsize=(10, 8))
# sns.heatmap(metrics_df, annot=True, cmap='viridis', fmt='.3f')
# plt.title('Performance Metrics Heatmap')
# plt.show()

# %%
# --- Table 1: Final Cumulative Returns Summary ---
import pandas as pd

print("--- Final Cumulative Returns ---")
if 'cumul_df' in locals() and isinstance(cumul_df, pd.DataFrame):
    # Display with better formatting for an article
    print(cumul_df.round(4).to_markdown(numalign="center", stralign="center"))
    # Or simply print
    # print(cumul_df.round(4))
else:
    print("Error: 'cumul_df' not found. Ensure the main cell ran successfully and calculated benchmark performances.")
# Out:
# --- Final Cumulative Returns ---
# |       |  cumulative_returns[-1]  |
# |:-----:|:------------------------:|
# |  MVO  |          0.3403          |
# |  HRP  |          0.5356          |
# |  DRL  |          0.8067          |
# | mCVAR |          0.9338          |

# %%
# --- Table 2: Key Performance Metrics Summary ---
import pandas as pd

print("\n--- Performance Metrics Summary (Test Period) ---")
if 'metrics_df' in locals() and isinstance(metrics_df, pd.DataFrame):
     # Display transposed for potentially better readability in some contexts
    print(metrics_df.T.round(4).to_markdown(numalign="center", stralign="center"))
    # Or display as is
    # print(metrics_df.round(4).to_markdown(numalign="center", stralign="center"))
else:
    print("Error: 'metrics_df' not found. Ensure the main cell ran successfully and calculated performance metrics.")
# Out:
# --- Performance Metrics Summary (Test Period) ---
# |                 |  Sharpe Ratio  |  Omega Ratio  |  Volatility  |  Max Drawdown  |  Sortino Ratio  |  Calmar Ratio  |  Tail Ratio  |  Risk Return  |  Skew   |  Kurtosis  |
# |:---------------:|:--------------:|:-------------:|:------------:|:--------------:|:---------------:|:--------------:|:------------:|:-------------:|:-------:|:----------:|
# |  MVO Portfolio  |     0.7273     |    1.1267     |    0.1182    |    -0.1542     |     1.0274      |     0.5498     |    0.8797    |    0.0677     | -0.1859 |   1.2861   |
# |  HRP Portfolio  |     1.2606     |    1.2342     |    0.1119    |    -0.1851     |      1.815      |     0.6837     |    1.0193    |    0.1025     | -0.3284 |   1.9711   |
# |  DRL Portfolio  |     1.4038     |    1.2629     |    0.1517    |    -0.1919     |     2.0185      |     0.9306     |    1.1024    |    0.1055     | -0.4894 |   2.5893   |
# ...

# %%
# --- Visualization A: Correlation Heatmap of Assets ---
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

print("\n--- Asset Correlation Heatmap (Based on Training Data Returns) ---")
if 'train_returns' in locals() and isinstance(train_returns, pd.DataFrame):
    corr_matrix = train_returns.corr()
    plt.figure(figsize=(15, 10))
    sns.heatmap(corr_matrix, cmap='coolwarm', annot=False, fmt=".2f", linewidths=.5) # Annot=True is too crowded for 44 assets
    plt.title('Correlation Matrix of Stock Returns (Training Period)')
    plt.xticks(fontsize=8, rotation=90)
    plt.yticks(fontsize=8)
    plt.tight_layout()
    plt.show()
else:
    print("Error: 'train_returns' DataFrame not found.")
# Out:
# --- Asset Correlation Heatmap (Based on Training Data Returns) ---

# %%
# --- Visualization B: Comparison of Portfolio Weights (End of Training) ---
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

print("\n--- Portfolio Weight Comparison (End of Training) ---")

weights_data = {}
strategies_present = []

if 'normalized_weights' in locals() and isinstance(normalized_weights, pd.Series):
    weights_data['DRL'] = normalized_weights
    strategies_present.append('DRL')
else:
    print("Warning: 'normalized_weights' (DRL) not found.")

if 'mvo_weights' in locals() and isinstance(mvo_weights, np.ndarray):
    # Ensure mvo_weights is aligned with tickers if it's just an array
    if len(mvo_weights) == len(Tickers):
         weights_data['MVO'] = pd.Series(mvo_weights, index=Tickers)
         strategies_present.append('MVO')
    else:
         print(f"Warning: Length mismatch for mvo_weights ({len(mvo_weights)}) and Tickers ({len(Tickers)}).")
else:
    print("Warning: 'mvo_weights' not found or not an array.")

if 'hrp_weights' in locals() and isinstance(hrp_weights, pd.Series):
    weights_data['HRP'] = hrp_weights
    strategies_present.append('HRP')
else:
    print("Warning: 'hrp_weights' not found or not a Series.")

if 'mcvar_weights' in locals() and isinstance(mcvar_weights, np.ndarray):
     # Ensure mcvar_weights is aligned with tickers if it's just an array
    if len(mcvar_weights) == len(Tickers):
        weights_data['mCVAR'] = pd.Series(mcvar_weights, index=Tickers)
        strategies_present.append('mCVAR')
    else:
        print(f"Warning: Length mismatch for mcvar_weights ({len(mcvar_weights)}) and Tickers ({len(Tickers)}).")
else:
    print("Warning: 'mcvar_weights' not found or not an array.")

if strategies_present:
    weights_comparison_df = pd.DataFrame(weights_data)
    # Filter out assets with very small weights across all plotted strategies for clarity
    weights_comparison_df_filtered = weights_comparison_df[weights_comparison_df.sum(axis=1) > 0.01] # Keep if sum > 1%

    if not weights_comparison_df_filtered.empty:
        weights_comparison_df_filtered.plot(kind='bar', figsize=(18, 8), width=0.8)
        plt.title('Comparison of Portfolio Weights by Strategy (End of Training - Non-Zero)')
        plt.ylabel('Weight')
        plt.xlabel('Ticker')
        plt.xticks(rotation=90, fontsize=8)
        plt.legend(title='Strategy')
        plt.tight_layout()
        plt.show()
    else:
        print("No significant weights to plot after filtering.")
else:
    print("No strategy weights found to compare.")
# Out:
# --- Portfolio Weight Comparison (End of Training) ---

# %%
# --- Visualization C: Returns Distribution (Test Period) ---
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

print("\n--- Daily Returns Distribution Comparison (Test Period) ---")

returns_data = {}
strategies_present_returns = []

# Use the daily returns calculated in the main cell
if 'drl_portfolio_returns' in locals() and isinstance(drl_portfolio_returns, pd.Series):
    returns_data['DRL'] = drl_portfolio_returns
    strategies_present_returns.append('DRL')
else:
    print("Warning: 'drl_portfolio_returns' not found.")

if 'mvo_portfolio_returns' in locals() and isinstance(mvo_portfolio_returns, pd.Series):
    returns_data['MVO'] = mvo_portfolio_returns
    strategies_present_returns.append('MVO')
else:
    print("Warning: 'mvo_portfolio_returns' not found.")

if 'hrp_portfolio_returns' in locals() and isinstance(hrp_portfolio_returns, pd.Series):
    returns_data['HRP'] = hrp_portfolio_returns
    strategies_present_returns.append('HRP')
else:
    print("Warning: 'hrp_portfolio_returns' not found.")

if 'mcvar_portfolio_returns' in locals() and isinstance(mcvar_portfolio_returns, pd.Series):
    returns_data['mCVAR'] = mcvar_portfolio_returns
    strategies_present_returns.append('mCVAR')
else:
    print("Warning: 'mcvar_portfolio_returns' not found.")


if strategies_present_returns:
    returns_comparison_df = pd.DataFrame(returns_data)

    plt.figure(figsize=(12, 7))
    sns.kdeplot(data=returns_comparison_df, fill=True, alpha=0.5, linewidth=1.5)
    plt.title('Distribution of Daily Portfolio Returns (Test Period)')
    plt.xlabel('Daily Return')
    plt.ylabel('Density')
    plt.grid(True, axis='y', alpha=0.5)
    plt.legend(title='Strategy', labels=strategies_present_returns)
    plt.show()

    # Alternative: Histograms
    # returns_comparison_df.plot(kind='hist', bins=50, alpha=0.6, figsize=(12, 7), title='Histogram of Daily Portfolio Returns (Test Period)')
    # plt.xlabel('Daily Return')
    # plt.show()
else:
    print("No portfolio returns found to plot distributions.")
# Out:
# --- Daily Returns Distribution Comparison (Test Period) ---

# %%
# --- Visualization D: Drawdown Plot (Test Period) ---
import matplotlib.pyplot as plt
import quantstats as qs
import pandas as pd

print("\n--- Drawdown Comparison (Test Period) ---")

# Check which cumulative return series are available
plot_series = {}
if 'drl_cumulative_returns' in locals() and isinstance(drl_cumulative_returns, pd.Series):
    plot_series['DRL'] = drl_cumulative_returns + 1 # Quantstats needs cumulative wealth (starts at 1)
else:
    print("Warning: 'drl_cumulative_returns' not found.")

if 'mvo_cumulative_returns' in locals() and isinstance(mvo_cumulative_returns, pd.Series):
    plot_series['MVO'] = mvo_cumulative_returns + 1
else:
    print("Warning: 'mvo_cumulative_returns' not found.")

if 'hrp_cumulative_returns' in locals() and isinstance(hrp_cumulative_returns, pd.Series):
    plot_series['HRP'] = hrp_cumulative_returns + 1
else:
    print("Warning: 'hrp_cumulative_returns' not found.")

if 'mcvar_cumulative_returns' in locals() and isinstance(mcvar_cumulative_returns, pd.Series):
    plot_series['mCVAR'] = mcvar_cumulative_returns + 1
else:
    print("Warning: 'mcvar_cumulative_returns' not found.")

if plot_series:
    # Combine into a DataFrame for plotting
    combined_cum_returns = pd.DataFrame(plot_series)

    # Calculate drawdowns manually for plotting flexibility
    cumulative_max = combined_cum_returns.cummax()
    drawdowns = (combined_cum_returns - cumulative_max) / cumulative_max

    plt.figure(figsize=(14, 7))
    drawdowns.plot(ax=plt.gca()) # Plot on the current axes
    plt.title('Portfolio Drawdowns During Test Period')
    plt.ylabel('Drawdown')
    plt.xlabel('Date')
    plt.grid(True, axis='y', alpha=0.5)
    plt.legend(title='Strategy')
    plt.show()

    # Quantstats alternative (creates its own figure)
    # try:
    #     qs.plots.drawdown(drl_portfolio_returns, cumulative=True, title="DRL Drawdown")
    #     qs.plots.drawdown(mvo_portfolio_returns, cumulative=True, title="MVO Drawdown")
    #     qs.plots.drawdown(hrp_portfolio_returns, cumulative=True, title="HRP Drawdown")
    #     qs.plots.drawdown(mcvar_portfolio_returns, cumulative=True, title="mCVAR Drawdown")
    #     plt.show() # Show all generated plots
    # except NameError as e:
    #     print(f"Could not generate quantstats drawdown plots: {e}")
    # except Exception as e:
    #     print(f"An error occurred with quantstats plotting: {e}")

else:
    print("No cumulative returns data found to plot drawdowns.")
# Out:
# --- Drawdown Comparison (Test Period) ---

# %%
# --- Visualization E: Rolling Volatility of Portfolio Returns ---
import matplotlib.pyplot as plt
import pandas as pd

print("\n--- Rolling Volatility Comparison (Test Period) ---")

# Use the daily returns series calculated in the main cell
rolling_window = 60 # e.g., 60 trading days (approx 3 months)
vol_data = {}
strategies_present_returns = []

if 'drl_portfolio_returns' in locals() and isinstance(drl_portfolio_returns, pd.Series):
    vol_data['DRL'] = drl_portfolio_returns.rolling(window=rolling_window).std() * (252**0.5) # Annualized
    strategies_present_returns.append('DRL')
else:
    print("Warning: 'drl_portfolio_returns' not found.")

if 'mvo_portfolio_returns' in locals() and isinstance(mvo_portfolio_returns, pd.Series):
    vol_data['MVO'] = mvo_portfolio_returns.rolling(window=rolling_window).std() * (252**0.5)
    strategies_present_returns.append('MVO')
else:
    print("Warning: 'mvo_portfolio_returns' not found.")

if 'hrp_portfolio_returns' in locals() and isinstance(hrp_portfolio_returns, pd.Series):
    vol_data['HRP'] = hrp_portfolio_returns.rolling(window=rolling_window).std() * (252**0.5)
    strategies_present_returns.append('HRP')
else:
    print("Warning: 'hrp_portfolio_returns' not found.")

if 'mcvar_portfolio_returns' in locals() and isinstance(mcvar_portfolio_returns, pd.Series):
    vol_data['mCVAR'] = mcvar_portfolio_returns.rolling(window=rolling_window).std() * (252**0.5)
    strategies_present_returns.append('mCVAR')
else:
    print("Warning: 'mcvar_portfolio_returns' not found.")

if strategies_present_returns:
    rolling_vol_df = pd.DataFrame(vol_data).dropna() # Drop initial NaNs from rolling window

    if not rolling_vol_df.empty:
        plt.figure(figsize=(14, 7))
        rolling_vol_df.plot(ax=plt.gca())
        plt.title(f'{rolling_window}-Day Rolling Annualized Volatility (Test Period)')
        plt.ylabel('Annualized Volatility')
        plt.xlabel('Date')
        plt.legend(title='Strategy')
        plt.grid(True, alpha=0.5)
        plt.show()
    else:
        print(f"Not enough data to compute rolling volatility with window {rolling_window}.")

else:
    print("No portfolio returns found to compute rolling volatility.")
# Out:
# --- Rolling Volatility Comparison (Test Period) ---

# %%
# --- Visualization F: Rolling Sharpe Ratio of Portfolio Returns ---
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

print("\n--- Rolling Sharpe Ratio Comparison (Test Period) ---")

rolling_window = 60 # e.g., 60 trading days
risk_free_rate = 0.0419 # Use the same RF rate as in metrics calculation
rf_daily = (1 + risk_free_rate)**(1/252) - 1 # Approximate daily risk-free rate

sharpe_data = {}
strategies_present_returns = []

# Function to calculate rolling Sharpe
def rolling_sharpe(returns, window, rf_daily):
    rolling_mean = returns.rolling(window=window).mean()
    rolling_std = returns.rolling(window=window).std()
    # Annualize - mean needs daily rf subtracted *before* annualizing
    annualized_excess_mean = (rolling_mean - rf_daily) * 252
    annualized_std = rolling_std * np.sqrt(252)
    return annualized_excess_mean / (annualized_std + 1e-8) # Add epsilon for stability


if 'drl_portfolio_returns' in locals() and isinstance(drl_portfolio_returns, pd.Series):
    sharpe_data['DRL'] = rolling_sharpe(drl_portfolio_returns, rolling_window, rf_daily)
    strategies_present_returns.append('DRL')
else:
    print("Warning: 'drl_portfolio_returns' not found.")

if 'mvo_portfolio_returns' in locals() and isinstance(mvo_portfolio_returns, pd.Series):
    sharpe_data['MVO'] = rolling_sharpe(mvo_portfolio_returns, rolling_window, rf_daily)
    strategies_present_returns.append('MVO')
else:
    print("Warning: 'mvo_portfolio_returns' not found.")

if 'hrp_portfolio_returns' in locals() and isinstance(hrp_portfolio_returns, pd.Series):
    sharpe_data['HRP'] = rolling_sharpe(hrp_portfolio_returns, rolling_window, rf_daily)
    strategies_present_returns.append('HRP')
else:
    print("Warning: 'hrp_portfolio_returns' not found.")

if 'mcvar_portfolio_returns' in locals() and isinstance(mcvar_portfolio_returns, pd.Series):
    sharpe_data['mCVAR'] = rolling_sharpe(mcvar_portfolio_returns, rolling_window, rf_daily)
    strategies_present_returns.append('mCVAR')
else:
    print("Warning: 'mcvar_portfolio_returns' not found.")


if strategies_present_returns:
    rolling_sharpe_df = pd.DataFrame(sharpe_data).dropna()

    if not rolling_sharpe_df.empty:
        plt.figure(figsize=(14, 7))
        rolling_sharpe_df.plot(ax=plt.gca())
        plt.title(f'{rolling_window}-Day Rolling Annualized Sharpe Ratio (Test Period)')
        plt.ylabel('Sharpe Ratio')
        plt.xlabel('Date')
        plt.legend(title='Strategy')
        plt.axhline(0, color='grey', linestyle='--', linewidth=0.8)
        plt.grid(True, alpha=0.5)
        plt.show()
    else:
        print(f"Not enough data to compute rolling Sharpe ratio with window {rolling_window}.")

else:
    print("No portfolio returns found to compute rolling Sharpe ratio.")
# Out:
# --- Rolling Sharpe Ratio Comparison (Test Period) ---

# %%
# --- Table 3: Top N Holdings Comparison (End of Training) ---
import pandas as pd
import numpy as np

print("\n--- Top 5 Holdings by Weight (End of Training) ---")

top_n = 5
top_holdings_data = {}
strategies_present = []

# Reuse the weights_data dictionary logic from Visualization B
weights_data = {}
if 'normalized_weights' in locals() and isinstance(normalized_weights, pd.Series):
    weights_data['DRL'] = normalized_weights
    strategies_present.append('DRL')
if 'mvo_weights' in locals() and isinstance(mvo_weights, np.ndarray) and len(mvo_weights) == len(Tickers):
    weights_data['MVO'] = pd.Series(mvo_weights, index=Tickers)
    strategies_present.append('MVO')
if 'hrp_weights' in locals() and isinstance(hrp_weights, pd.Series):
    weights_data['HRP'] = hrp_weights
    strategies_present.append('HRP')
if 'mcvar_weights' in locals() and isinstance(mcvar_weights, np.ndarray) and len(mcvar_weights) == len(Tickers):
    weights_data['mCVAR'] = pd.Series(mcvar_weights, index=Tickers)
    strategies_present.append('mCVAR')


if strategies_present:
    weights_comparison_df = pd.DataFrame(weights_data)

    for strategy in strategies_present:
        top_holdings = weights_comparison_df[strategy].nlargest(top_n)
        top_holdings_data[f'{strategy}_Ticker'] = top_holdings.index.tolist()
        top_holdings_data[f'{strategy}_Weight'] = top_holdings.values.round(4).tolist()

    # Ensure all lists have the same length for DataFrame creation (pad if needed)
    max_len = top_n
    for key in top_holdings_data:
        while len(top_holdings_data[key]) < max_len:
            top_holdings_data[key].append(None) # Or '' or np.nan

    top_holdings_df = pd.DataFrame(top_holdings_data)
    print(top_holdings_df.to_markdown(index=False, numalign="center", stralign="center"))

else:
    print("No strategy weights found to compare top holdings.")
# Out:
# --- Top 5 Holdings by Weight (End of Training) ---
# |  DRL_Ticker   |  DRL_Weight  |  MVO_Ticker   |  MVO_Weight  |  HRP_Ticker   |  HRP_Weight  |  mCVAR_Ticker  |  mCVAR_Weight  |
# |:-------------:|:------------:|:-------------:|:------------:|:-------------:|:------------:|:--------------:|:--------------:|
# |  SHREECEM.NS  |    0.3009    | ULTRACEMCO.NS |    0.1871    | HINDUNILVR.NS |    0.0509    |  POWERGRID.NS  |       1        |
# | ULTRACEMCO.NS |    0.1788    |    ONGC.NS    |    0.1681    | POWERGRID.NS  |    0.0449    | GODREJPROP.NS  |       0        |
# | BRITANNIA.NS  |    0.1077    | BRITANNIA.NS  |    0.1016    | BRITANNIA.NS  |    0.0435    |     IOC.NS     |       0        |
# | HINDUNILVR.NS |    0.0751    |  HCLTECH.NS   |    0.0929    | NESTLEIND.NS  |    0.0413    | APOLLOHOSP.NS  |       0        |
# |    INFY.NS    |    0.058     | NESTLEIND.NS  |    0.0876    |   CIPLA.NS    |    0.0407    | ASIANPAINT.NS  |       0        |

# %%
# --- Visualization G: Monthly Returns Heatmap (Test Period) ---
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import quantstats as qs # Use quantstats for easy monthly returns

print("\n--- Monthly Returns Heatmap (Test Period) ---")

# Re-check which returns series are available
returns_series_dict = {}
if 'drl_portfolio_returns' in locals() and isinstance(drl_portfolio_returns, pd.Series):
    returns_series_dict['DRL'] = drl_portfolio_returns
else:
    print("Warning: 'drl_portfolio_returns' not found.")

if 'mvo_portfolio_returns' in locals() and isinstance(mvo_portfolio_returns, pd.Series):
    returns_series_dict['MVO'] = mvo_portfolio_returns
else:
    print("Warning: 'mvo_portfolio_returns' not found.")

if 'hrp_portfolio_returns' in locals() and isinstance(hrp_portfolio_returns, pd.Series):
    returns_series_dict['HRP'] = hrp_portfolio_returns
else:
    print("Warning: 'hrp_portfolio_returns' not found.")

if 'mcvar_portfolio_returns' in locals() and isinstance(mcvar_portfolio_returns, pd.Series):
    returns_series_dict['mCVAR'] = mcvar_portfolio_returns
else:
    print("Warning: 'mcvar_portfolio_returns' not found.")


if returns_series_dict:
    # Use quantstats to get monthly returns table easily for each series
    monthly_returns_list = []
    strategy_names = []
    for name, series in returns_series_dict.items():
        try:
            monthly_ret = qs.stats.monthly_returns(series)
            monthly_ret.columns = pd.MultiIndex.from_product([[name], monthly_ret.columns]) # Add strategy name level
            monthly_returns_list.append(monthly_ret)
            strategy_names.append(name)
        except Exception as e:
            print(f"Could not calculate monthly returns for {name}: {e}")

    if monthly_returns_list:
        # Combine the monthly returns - this might get wide
        # Let's plot separate heatmaps or a combined bar chart instead for clarity

        fig, axes = plt.subplots(len(monthly_returns_list), 1, figsize=(12, 4 * len(monthly_returns_list)), sharex=True)
        if len(monthly_returns_list) == 1: # Handle case of single strategy
            axes = [axes]

        for i, monthly_ret_df in enumerate(monthly_returns_list):
            strategy_name = strategy_names[i]
            # Drop the strategy name level for plotting
            plot_df = monthly_ret_df[strategy_name].drop(columns=['EOY'], errors='ignore') # Drop EOY summary if present
            sns.heatmap(plot_df.fillna(0), ax=axes[i], annot=True, fmt=".1%", cmap="viridis", center=0, linewidths=0.5, cbar=False)
            axes[i].set_title(f'Monthly Returns Heatmap - {strategy_name}')
            axes[i].tick_params(axis='x', rotation=45)
            axes[i].set_ylabel('Year')

        plt.tight_layout()
        plt.show()

    else:
        print("No monthly returns dataframes generated.")

else:
    print("No portfolio returns found to generate monthly heatmap.")
# Out:
# --- Monthly Returns Heatmap (Test Period) ---

# %%
# --- Visualization H: Box Plot of Daily Returns (Test Period) ---
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

print("\n--- Box Plot of Daily Returns (Test Period) ---")

# Reuse the returns_comparison_df from Visualization C logic
returns_data = {}
strategies_present_returns = []
if 'drl_portfolio_returns' in locals() and isinstance(drl_portfolio_returns, pd.Series):
    returns_data['DRL'] = drl_portfolio_returns
    strategies_present_returns.append('DRL')
if 'mvo_portfolio_returns' in locals() and isinstance(mvo_portfolio_returns, pd.Series):
    returns_data['MVO'] = mvo_portfolio_returns
    strategies_present_returns.append('MVO')
if 'hrp_portfolio_returns' in locals() and isinstance(hrp_portfolio_returns, pd.Series):
    returns_data['HRP'] = hrp_portfolio_returns
    strategies_present_returns.append('HRP')
if 'mcvar_portfolio_returns' in locals() and isinstance(mcvar_portfolio_returns, pd.Series):
    returns_data['mCVAR'] = mcvar_portfolio_returns
    strategies_present_returns.append('mCVAR')

if strategies_present_returns:
    returns_comparison_df = pd.DataFrame(returns_data)

    plt.figure(figsize=(10, 6))
    sns.boxplot(data=returns_comparison_df, palette='viridis')
    plt.title('Box Plot of Daily Portfolio Returns (Test Period)')
    plt.ylabel('Daily Return')
    plt.xlabel('Strategy')
    plt.grid(True, axis='y', alpha=0.5)
    plt.show()
else:
    print("No portfolio returns found to generate box plot.")
# Out:
# --- Box Plot of Daily Returns (Test Period) ---

# %%
# --- Visualization I: Nifty 50 Index Performance ---
import matplotlib.pyplot as plt
import pandas as pd

print("\n--- Nifty 50 Index Performance (Full Period) ---")

if 'nsei_df' in locals() and isinstance(nsei_df, pd.DataFrame) and 'Close' in nsei_df.columns:
    plt.figure(figsize=(16, 7))
    plt.plot(nsei_df.index, nsei_df['Close'], label='Nifty 50 Index')

    # Add vertical lines for train/test split
    if 'end_train' in locals():
        plt.axvline(end_train, color='red', linestyle='--', label='End of Train Period')
    if 'start_test' in locals():
        plt.axvline(start_test, color='green', linestyle='--', label='Start of Test Period')


    plt.title('Nifty 50 Index (^NSEI) Closing Prices')
    plt.xlabel('Date')
    plt.ylabel('Index Value')
    plt.yscale('log') # Use log scale for better visualization of long-term trends
    plt.legend()
    plt.grid(True, which="both", ls="--", linewidth=0.5)
    plt.show()
else:
    print("Error: 'nsei_df' DataFrame with 'Close' column not found.")
# Out:
# --- Nifty 50 Index Performance (Full Period) ---

# %%
# --- Table 4: PPO Hyperparameter Summary ---
import pandas as pd

print("\n--- PPO Agent Hyperparameters Used ---")

# Extract parameters used in the train_ppo call in the main cell
# If defaults were used, list them. If variables were used, list the variable values.
# Example using the defaults shown in the function definition:
hyperparameters = {
    'Parameter': [
        'Training Episodes',
        'Gamma (Discount Factor)',
        'Epsilon (Exploration Rate - Initial)', # Assuming it might decay or wasn't used if argmax is always taken
        'Clip Epsilon (PPO Clip)',
        'Update Steps per Batch',
        'Batch Size',
        'Learning Rate (Optimizer)',
        'Early Stopping Threshold',
        'Early Stopping Patience',
        'State Dimension (Calculated)',
        'Action Dimension (Calculated)'
    ],
    'Value': [
        250, # Value used in the call, or the default
        0.997,
        0.08, # Note: Your code uses argmax if random()<epsilon isn't met, not standard epsilon-greedy
        0.15,
        20,
        128,
        0.0005, # Assuming this was the lr used in the final call
        0.002,
        60,
        state_dim if 'state_dim' in locals() else 'Not Found',
        action_dim if 'action_dim' in locals() else 'Not Found'
     ]
}

hp_df = pd.DataFrame(hyperparameters)
print(hp_df.to_markdown(index=False, numalign="center", stralign="center"))

# Add notes if necessary:
print("\n*Note: Epsilon behavior deviates from standard epsilon-greedy; random action taken with probability epsilon, otherwise argmax.*")
# Out:
# --- PPO Agent Hyperparameters Used ---
# |              Parameter               |  Value  |
# |:------------------------------------:|:-------:|
# |          Training Episodes           |   250   |
# |       Gamma (Discount Factor)        |  0.997  |
# | Epsilon (Exploration Rate - Initial) |  0.08   |
# |       Clip Epsilon (PPO Clip)        |  0.15   |
# |        Update Steps per Batch        |   20    |
# |              Batch Size              |   128   |
# |      Learning Rate (Optimizer)       | 0.0005  |
# |       Early Stopping Threshold       |  0.002  |
# |       Early Stopping Patience        |   60    |
# |     State Dimension (Calculated)     |   664   |
# |    Action Dimension (Calculated)     |   132   |
#
# *Note: Epsilon behavior deviates from standard epsilon-greedy; random action taken with probability epsilon, otherwise argmax.*

# %%
# --- Visualization J: HRP Dendrogram ---
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import linkage, dendrogram
from scipy.spatial.distance import squareform
import pandas as pd

print("\n--- Hierarchical Risk Parity (HRP) Dendrogram (Based on Training Data) ---")

if 'train_returns' in locals() and isinstance(train_returns, pd.DataFrame):
    corr = train_returns.corr()
    dist = squareform(((1 - corr) / 2.)**.5) # Distance matrix
    link = linkage(dist, 'single') # Perform single linkage clustering

    plt.figure(figsize=(15, 7))
    dendrogram(link,
               labels=corr.index.tolist(),
               orientation='top',
               leaf_rotation=90.,
               leaf_font_size=8.)
    plt.title('HRP Dendrogram - Asset Clustering (Training Period)')
    plt.xlabel('Assets')
    plt.ylabel('Distance')
    plt.tight_layout()
    plt.show()
else:
    print("Error: 'train_returns' DataFrame not found.")
# Out:
# --- Hierarchical Risk Parity (HRP) Dendrogram (Based on Training Data) ---

# %%
# --- Table 5: Annualized Performance Metrics ---
import pandas as pd
import numpy as np
import quantstats as qs

print("\n--- Annualized Performance Metrics Summary (Test Period) ---")

annualized_metrics = {}
strategies_present_returns = []
risk_free_rate = 0.0419 # Ensure consistency

# Reuse the returns series gathering logic
returns_series_dict = {}
if 'drl_portfolio_returns' in locals() and isinstance(drl_portfolio_returns, pd.Series): returns_series_dict['DRL'] = drl_portfolio_returns
if 'mvo_portfolio_returns' in locals() and isinstance(mvo_portfolio_returns, pd.Series): returns_series_dict['MVO'] = mvo_portfolio_returns
if 'hrp_portfolio_returns' in locals() and isinstance(hrp_portfolio_returns, pd.Series): returns_series_dict['HRP'] = hrp_portfolio_returns
if 'mcvar_portfolio_returns' in locals() and isinstance(mcvar_portfolio_returns, pd.Series): returns_series_dict['mCVAR'] = mcvar_portfolio_returns


if returns_series_dict:
    for name, returns in returns_series_dict.items():
        try:
            # Calculate annualized metrics using quantstats or manually
            ann_ret = qs.stats.cagr(returns) # Compound Annual Growth Rate
            ann_vol = qs.stats.volatility(returns, periods=252, annualize=True)
            sharpe = qs.stats.sharpe(returns, rf=risk_free_rate, periods=252, annualize=True)
            annualized_metrics[name] = [ann_ret, ann_vol, sharpe]
            strategies_present_returns.append(name)
        except Exception as e:
            print(f"Could not calculate annualized metrics for {name}: {e}")

    if annualized_metrics:
        ann_metrics_df = pd.DataFrame(annualized_metrics, index=['Annualized Return (CAGR)', 'Annualized Volatility', 'Annualized Sharpe Ratio'])
        # Display transposed for better comparison across strategies
        print(ann_metrics_df.T.round(4).to_markdown(numalign="center", stralign="center"))
    else:
        print("No annualized metrics could be calculated.")
else:
    print("No portfolio returns found to calculate annualized metrics.")
# Out:
# --- Annualized Performance Metrics Summary (Test Period) ---
# |       |  Annualized Return (CAGR)  |  Annualized Volatility  |  Annualized Sharpe Ratio  |
# |:-----:|:--------------------------:|:-----------------------:|:-------------------------:|
# |  DRL  |           0.1786           |         0.1517          |          1.4038           |
# |  MVO  |           0.0848           |         0.1182          |          0.7273           |
# |  HRP  |           0.1266           |         0.1119          |          1.2606           |
# | mCVAR |           0.2011           |         0.3065          |          0.9017           |

# %%
# --- Table 7: Downside Risk Metrics (VaR & CVaR) ---
import pandas as pd
import numpy as np

print("\n--- Downside Risk Metrics (95% VaR & CVaR - Daily, Test Period) ---")

downside_metrics = {}
strategies_present_returns = []
confidence_level = 0.95

# Function to calculate Historical VaR and CVaR
def calculate_var_cvar(returns, confidence=0.95):
    if returns.empty:
        return np.nan, np.nan
    var = np.percentile(returns, 100 * (1 - confidence))
    cvar = returns[returns <= var].mean()
    return var, cvar

# Gather the daily returns series again
returns_series_dict = {}
if 'drl_portfolio_returns' in locals() and isinstance(drl_portfolio_returns, pd.Series): returns_series_dict['DRL'] = drl_portfolio_returns
if 'mvo_portfolio_returns' in locals() and isinstance(mvo_portfolio_returns, pd.Series): returns_series_dict['MVO'] = mvo_portfolio_returns
if 'hrp_portfolio_returns' in locals() and isinstance(hrp_portfolio_returns, pd.Series): returns_series_dict['HRP'] = hrp_portfolio_returns
if 'mcvar_portfolio_returns' in locals() and isinstance(mcvar_portfolio_returns, pd.Series): returns_series_dict['mCVAR'] = mcvar_portfolio_returns


if returns_series_dict:
    for name, returns in returns_series_dict.items():
        try:
            daily_var, daily_cvar = calculate_var_cvar(returns.dropna(), confidence=confidence_level)
            downside_metrics[name] = [f"{daily_var:.2%}", f"{daily_cvar:.2%}"]
            strategies_present_returns.append(name)
        except Exception as e:
            print(f"Could not calculate VaR/CVaR for {name}: {e}")

    if downside_metrics:
        downside_df = pd.DataFrame(downside_metrics, index=[f'Daily VaR ({confidence_level*100:.0f}%)', f'Daily CVaR ({confidence_level*100:.0f}%)'])
        print(downside_df.T.to_markdown(numalign="center", stralign="center")) # Transposed
    else:
        print("No downside risk metrics could be calculated.")
else:
    print("No portfolio returns found to calculate downside risk.")
# Out:
# --- Downside Risk Metrics (95% VaR & CVaR - Daily, Test Period) ---
# |       |  Daily VaR (95%)  |  Daily CVaR (95%)  |
# |:-----:|:-----------------:|:------------------:|
# |  DRL  |      -1.41%       |       -2.11%       |
# |  MVO  |      -1.27%       |       -1.64%       |
# |  HRP  |      -1.13%       |       -1.62%       |
# | mCVAR |      -2.99%       |       -4.13%       |

# %%
# --- Visualization L: Correlation Heatmap of Portfolio Strategy Returns ---
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

print("Correlation Heatmap of Portfolio Strategy Daily Returns (Test Period)")

# Reuse returns_comparison_df logic from Visualization C/H
returns_data = {}
strategies_present_returns = []
if 'drl_portfolio_returns' in locals() and isinstance(drl_portfolio_returns, pd.Series): returns_data['DRL'] = drl_portfolio_returns; strategies_present_returns.append('DRL')
if 'mvo_portfolio_returns' in locals() and isinstance(mvo_portfolio_returns, pd.Series): returns_data['MVO'] = mvo_portfolio_returns; strategies_present_returns.append('MVO')
if 'hrp_portfolio_returns' in locals() and isinstance(hrp_portfolio_returns, pd.Series): returns_data['HRP'] = hrp_portfolio_returns; strategies_present_returns.append('HRP')
if 'mcvar_portfolio_returns' in locals() and isinstance(mcvar_portfolio_returns, pd.Series): returns_data['mCVAR'] = mcvar_portfolio_returns; strategies_present_returns.append('mCVAR')

if len(strategies_present_returns) > 1:
    returns_comparison_df = pd.DataFrame(returns_data)
    strategy_corr = returns_comparison_df.corr()

    plt.figure(figsize=(8, 6))
    sns.heatmap(strategy_corr, annot=True, cmap='viridis', fmt=".2f", linewidths=.5)
    plt.title('Correlation Between Portfolio Strategy Daily Returns (Test Period)')
    plt.xticks(rotation=45, ha='right')
    plt.yticks(rotation=0)
    plt.tight_layout()
    plt.show()
elif len(strategies_present_returns) == 1:
     print("Only one strategy's returns found, cannot compute correlation matrix.")
else:
    print("No portfolio returns found to compute correlation.")
# Out:
# --- Correlation Heatmap of Portfolio Strategy Daily Returns (Test Period) ---

# %%
# --- Table 8: Portfolio Concentration (Herfindahl Index - HHI) ---
import pandas as pd
import numpy as np

print("\n--- Portfolio Concentration (Herfindahl Index - HHI, End of Training Weights) ---")

hhi_data = {}
strategies_present = []

# Function to calculate HHI
def calculate_hhi(weights):
    if weights is None or len(weights) == 0:
        return np.nan
    # Ensure weights sum to 1 (or close enough) for meaningful HHI
    weights = weights / np.sum(weights)
    return np.sum(weights**2)

# Reuse the weights_data dictionary logic from Visualization B
weights_data = {}
if 'normalized_weights' in locals() and isinstance(normalized_weights, pd.Series):
    weights_data['DRL'] = normalized_weights.values # Use numpy array
    strategies_present.append('DRL')
if 'mvo_weights' in locals() and isinstance(mvo_weights, np.ndarray):
    weights_data['MVO'] = mvo_weights
    strategies_present.append('MVO')
if 'hrp_weights' in locals() and isinstance(hrp_weights, pd.Series):
    weights_data['HRP'] = hrp_weights.values
    strategies_present.append('HRP')
if 'mcvar_weights' in locals() and isinstance(mcvar_weights, np.ndarray):
    weights_data['mCVAR'] = mcvar_weights
    strategies_present.append('mCVAR')

if strategies_present:
    for strategy in strategies_present:
        hhi = calculate_hhi(weights_data[strategy])
        hhi_data[strategy] = [f"{hhi:.4f}"] # Format as float string

    if hhi_data:
        hhi_df = pd.DataFrame(hhi_data, index=['HHI (Higher=Concentrated)'])
        print(hhi_df.T.to_markdown(numalign="center", stralign="center"))
    else:
        print("Could not calculate HHI for any strategy.")
else:
    print("No strategy weights found to calculate HHI.")
# Out:
# --- Portfolio Concentration (Herfindahl Index - HHI, End of Training Weights) ---
# |       |  HHI (Higher=Concentrated)  |
# |:-----:|:---------------------------:|
# |  DRL  |           0.1516            |
# |  MVO  |           0.1086            |
# |  HRP  |           0.0286            |
# | mCVAR |              1              |
